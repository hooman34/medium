# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import random
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# outlier graph

# %%
data = dict()
data['numbers1'] = list(np.random.rand(30))
data['numbers2'] = list(np.random.rand(30))

data['numbers1'].extend([20, 19, 21])
data['numbers2'].extend([20, 18, 23])

df = pd.DataFrame(data)

# %%
figure(figsize=(8, 6), dpi=80)

plt.scatter(data['numbers1'], data['numbers2'], alpha=0.8);

plt.savefig('plots/outlier_scatter.png')

# %% [markdown]
# peaks over threshold

# %%
base = datetime.datetime.today()
date_list = [base - datetime.timedelta(days=x) for x in range(365)]

data = dict()
data['date'] = date_list
data['values'] = np.random.uniform(low=0, high=80, size=365)

extreme = np.random.uniform(low=100, high=150, size=5)
for i, random_integer in enumerate(np.random.randint(low=0, high=365, size=5)):
    data['values'][random_integer] = extreme[i]
    
df = pd.DataFrame(data)

# %%
figure(figsize=(8, 6), dpi=80)

plt.scatter(data['date'], data['values'], alpha=0.8);
plt.plot(data['date'], line, '--', color='#fcba03');

plt.savefig('plots/peaks_over_threshold.png')
